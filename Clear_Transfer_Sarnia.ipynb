# %%
import pandas as pd
import time
import datetime

# 🕒 Start timer
start_time = time.time()
last_timestamp = start_time
print("Clearance Transfer Start:", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# -----------------------------
# Read CSV safely
# -----------------------------


df = pd.read_csv('clearance_transfer_input_sarnia.csv', sep=',')  # use ',' if comma-separated

# Clean column headers

df.columns = df.columns.str.strip().str.replace('\n','').str.replace('\r','')


# This will store units sold per SKU per store
units_sold_db = {}  # key = SKU, value = dict of {store: sold_items}

sales_columns = {
    'Chatham': 'Chatham',
    'Exmouth': 'Exmouth',
    'Lakeshore': 'Lakeshore',
    'Trudeau': 'Trudeau'
}

inv_columns = {
    'Chatham': 'ChathamInv',
    'Exmouth': 'ExmouthInv',
    'Lakeshore': 'LakeshoreInv',
    'Trudeau': 'TrudeauInv'
}


# Ensure numeric columns are integers
for col in list(sales_columns.values()) + list(inv_columns.values()):
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)

# Save initial sales for fallback
initial_sales = df[list(sales_columns.values())].copy()


# function to calculate units sold per iteration
# Initialize the database at the start
units_sold_db = {}  # key = SKU, value = dict of {store: sold_items}
    
# Transfer logic starts
# -----------------------------
transfers = []

updated_available_numbers = {store: [] for store in sales_columns.keys()}


# Function to calculate units sold for a single store (unchanged)
def calculate_units_sold(index, store):
    


    """
    Calculate units sold per SKU and store.
    """
#    print("Shank in calculate_units_sold function")
    sold_items = 0
    sales = df.loc[index, sales_columns[store]]
    inventory = df.loc[index, inv_columns[store]]
#    print("SHANK in CALCULATE_UNITS_SOLD: ")
#    print("SHANK QWE inventory: ", inventory)
#    print("SHANK QWE sales: ", sales)
    
    if inventory > sales:
        for i in range(inventory, sales, -1):
            sold_items += 1
    else:
        if inventory == sales:
            sold_items = 0
#    print("Shank sold_items: ", sold_items)
    return sold_items


def get_units_sold_array(index):
    
    """ Captures initial units sold
    Calculate units sold for all stores for a given SKU
    and store it in an array of tuples: (store_name, sold_items)
    """
#    print("Shank in get_units_sold_array function")
    units_sold_array = []
    for store in sales_columns.keys():
        sold_items = calculate_units_sold(index, store)  # recalculate per iteration
        units_sold_array.append((store, sold_items))
    return units_sold_array


# Determine DONOR Store
def select_donor(index):
#    print("Shank Entered select_donor function")
    
    """
    Select a single donor store for a given SKU.
    - Calculates units sold for each store dynamically.
    - Finds the store with the largest difference: inventory - sold_items.
    - Sets a flag to indicate whether a donor was found.
    - If no eligible donor, calls No_donor().
    Returns:
        donor (str or None): selected donor store
        donor_found (bool): True if donor found, False if fallback
    """
    donor = None
    donor_found = False
    donor_no_sale = False
    transfer_possible = True

#    max_excess = -float('inf')  # start very small to ensure any positive excess is considered
    max_excess = initial_sales.loc[index].max()  # max initial sale among all stores for this SKU
    

    # Calculate units sold array for all stores
    units_sold_array = get_units_sold_array(index)
#    print(f"Shank | SKU={df.loc[index, 'SKU']} | Units Sold Array={units_sold_array} | Max Excess={max_excess}")
    print(f"Shank | SKU={df.loc[index, 'SKU']} | Units Sold Array={units_sold_array}")
    
    # Determine donor based on max (inventory - sold_items)
#    print("Shank about to enter no_sale function")
#    no_sale(index)
#    print("Shank post no_sale function", sales_made)
#    for store, sold in units_sold_array:
    sales_made = True
    if sales_made:
#        print("SHANK sales_made for this sku: ", index)
        while transfer_possible:
#            print("SHANK Start of WHILE")
            for store, inv_col in inv_columns.items():
                inventory = df.loc[index, inv_columns[store]]
#                print("Shank Store BF", store)
#                print("Shank Inventory BF", inventory)
#               print("Shank sold BF", sold)
                excess = 0
                donor_no_sale = False 
#               print("Shank excess", excess)
#               print("Shank donor_no_sale", donor_no_sale)
#               print("SHANK Calculate inventory here")
#               print("SHANK add a while loop for following functionality until Almost_equal flag is set)
#                print("calculate units_sold_array here ")
                sold = calculate_units_sold(index, store)
#                print("SHANK Store", store)
#                print("SHANK inventory: ", inventory)
#                print("Shank Units sold AF: ", sold)

                if (inventory > 0) and (sold < inventory):
#                    print("SHANK Trigger logic #1")
#                    print("Shank donor store: ", store)
#                    print("SHANK donor inventory: ", inventory)
#                    print("Shank donor sold: ", sold)
                    transfer_log(index, store)
#                    print("Shank 1 unit moved")
                    sold = calculate_units_sold(index, store)
                    break
#                   print("SHANK add and subtract inventory and sales")
#                elif( inventory == 0) and (sold < inventory):
#                    print("SHANK elif trigger transfer logic")
#                else:
#                    print("go to next sku")
            
#            print("SHANK 1 UNIT MOVED")
#            print("Post transfer calculations for another check")
            if do_not_transfer == True:
                break
            transfer_possible = False
            for store, inv_col in inv_columns.items():
                post_inventory = df.loc[index, inv_columns[store]]
                post_sold = calculate_units_sold(index, store)
                post_sales = df.loc[index, sales_columns[store]]
#                print("SHANK Store: ", store)
#                print("SHANK post_sales: ", post_sales)
#                print("SHANK post_sold: ", post_sold)
#                print("SHANK post_inventory: ", post_inventory)
                if post_inventory > 0:
                    if (post_inventory - post_sold > 1):
#                         print ("Shank setting transfer_possible to True")
                         transfer_possible = True
                         break
                    elif (post_inventory > post_sold ):
#                         print ("SHANK inventory - sold = 1")
                         transfer_possible = True
                         break
                    else:
#                         print ("Shank setting transfer_possible to False")
                         transfer_possible = False
    
            
    # Fallback if no donor found
    if donor is None:
        donor = None
        donor_found = False
    return donor, donor_found



# Determine Receiver Store
def select_receiver(index):
    
    """
    Select a receiver store for a given SKU.
    - Calculates units sold for all stores dynamically.
    - Chooses the store with the **highest units sold**.
    - Handles both positive and negative sales correctly.
    Returns:
        receiver (str): store selected to receive units
    """
    global receiver_sold
#    print("Shank in select_receiver function")
    # Calculate units sold array for all stores
    units_sold_array = get_units_sold_array(index)

#    print("Shank before selecting receiver")
    # Select store with maximum units sold
    receiver = max(units_sold_array, key=lambda x: x[1])[0]  # x[1] is sold_items
#    print("Shank post receiver selection", receiver)

    return receiver

def fallback_transfer(donor):
    pass
    
def no_sale(index):
#    print("Shank in no_sale function")
    global sales_made
    sales_made = True
#    print ("SHANK START sales_made: ", sales_made)
    for store, inv_col in inv_columns.items():
        inventory = df.loc[index, inv_columns[store]]
        sold_units = calculate_units_sold(index, store)
##        print("Shank Store AF", store)
#        print("Shank Inventory AF", inventory)
#        print("Shank sold AF", sold_units)
        if ( sold_units == 0):
#            print("SHank set sales_made false")
            sales_made = False
        else:
 #           print ("Shank set sales_made true")
            sales_made = True
            break
 #   print ("Shank AF sales_made: ", sales_made)
    if (not sales_made):
#        print("SHANK no sale transfer logic")
        no_sale_donor = None
        for store, inv_col in inv_columns.items():
            no_sale_inv = df.loc[index, inv_columns[store]]
            if (no_sale_inv > 0):
#                print ("SHANK Store: ", store)
#                print ("SHANK inventory: ", no_sale_inv )
                no_sale_donor = store
                no_sale_receiver = "Huron"
                if (no_sale_donor == no_sale_receiver):
#                    print("SHANK receiver = donor = Huron")
                    no_sale_receiver = "Tecumseh"
                df.loc[index, inv_columns[no_sale_donor]] -= 1
                df.loc[index, sales_columns[no_sale_receiver]] += 1
                
                transfers.append({
                    'SKU': df.loc[index, 'SKU'],
                    'Product Name': df.loc[index, 'Product Name'],
                    'Category': df.loc[index, 'Category'],
                    'From Store': no_sale_donor,
                    'To Store': no_sale_receiver,
                    'Amount': 1
                })
#                print("SHANK no sale Transfer Written")
                break
#    print("end of no_sale function sales_made: ", sales_made)
     
    
def transfer_log(index, store):
    """
    Executes a single transfer from donor to receiver and logs it.
    Uses your existing `transfers` list.
    """
#    print("TRIP in transfer_log")
    global do_not_transfer
    do_not_transfer = False
    global transfers  # so that appends affect the main list
    donor = store
    # 1️⃣ Determine the receiver dynamically
    
    receiver = select_receiver(index)
#    print("Shank receiver: -",receiver)
    receiver_units_sold = calculate_units_sold(index, receiver)
    donor_units_sold = calculate_units_sold(index, donor)
#    print("Shank DONOR: -",donor)
#    print("SHASHANK donor_units_sold: ", donor_units_sold)
#    print("SHASHANK recevier_units_sold: ", receiver_units_sold)
    donor_sales = df.loc[index, sales_columns[donor]]
    donor_inventory = df.loc[index, inv_columns[donor]]
    
    
    # 2️⃣ Skip if donor and receiver are the same
    if (donor == receiver):
#        print("SHANK RETURN")
        do_not_transfer = True
        return
#    if (donor_inventory - donor_sales < 1):
#        return
#    if (donor_inventory < donor_sales ):
#        return
    
#    if (donor_inventory - donor_sold > 1):
#    print("TRIP Before Loop")
#    if receiver == "Dougall" and receiver_units_sold == 0:
#        receiver = "Huron"
#        print("@@@@@@@@@@@@@")
#        if donor == receiver:
#            print("#############")
#            receiver = "Tecumseh"
    # 3️⃣ Update inventory and sales
    
    
    print("Shashank donor FINAL : ", donor)
    print("Shashank receiver FINAL : ", receiver)
    current_sales = df.loc[index, sales_columns[receiver]]
    df.loc[index, inv_columns[donor]] -= 1
    df.loc[index, sales_columns[donor]] -= 1
#********************* new code**************
    df.loc[index, inv_columns[receiver]] +=1
    df.loc[index, sales_columns[receiver]] +=1
#********************* new code***************    
#    print("Updated donor inventory:", df.loc[index, inv_columns[donor]])
#    print("Updated donor Sales:", df.loc[index, sales_columns[donor]])
#    print("Updated receiver Sales:", df.loc[index, sales_columns[receiver]])
#    print("Updated receiver inventory:", df.loc[index, inv_columns[receiver]])
#    print ("SHANK Donor: ", donor)
#    print ("SHANK Donor Sales: ", donor_sales)
#        if donor_sales >= 0:
#            df.loc[index, sales_columns[donor]] -= 1
#    print("TRIP current_Sales", current_sales)
#    if current_sales > 0:
#         print(" TRIP #1")
#        df.loc[index, sales_columns[receiver]] -= 1
#        df.loc[index, inv_columns[receiver]] += 1
#    elif current_sales <= 0:
#         print("TRIP #2!")
#        df.loc[index, inv_columns[receiver]] += 1
#        df.loc[index, sales_columns[receiver]] += 1 

#    elif current_sales == 0:
#        if receiver == "Dougall":
#           print("TRIP 2")
#           dougall_sold = calculate_units_sold(index, "Dougall")
#           if dougall_sold == 0:
#               print("TRIP 3")
#               print("**********TRANSFER DEBUG INFO*************")
#               print("SKU: ", df.loc[index, 'SKU'])
#               print("Donor: ", donor)
#               print("Receiver: ", receiver)
#               print("Items transfered: 10")
#               print("***********TRANSFER INFO END**************")
               
#               transfers.append({
#                   'SKU': df.loc[index, 'SKU'],
#                   'Product Name': df.loc[index, 'Product Name'],
#                   'Category': df.loc[index, 'Category'],
#                  'From Store': donor,
#                   'To Store': receiver,
#                   'Amount': 9
#               })

    # 4️⃣ Log the transfer
    transfers.append({
            'SKU': df.loc[index, 'SKU'],
            'Product Name': df.loc[index, 'Product Name'],
            'Category': df.loc[index, 'Category'],
            'From Store': donor,
            'To Store': receiver,
            'Amount': 1
        })

def check_almost_equal():
    pass

# -----------------------------
# Transfer logic loop start
# -----------------------------

# -----------------------------
# Main module before transfer logic
# -----------------------------



# print("Entering Main Loop")
status_interval = 15  # seconds
last_status_time = time.time()

for index in df.index:  # Loop through each SKU
    sku = df.loc[index, 'SKU']
    product_name = df.loc[index, 'Product Name']
    category = df.loc[index, 'Category']
    current_time = time.time()
    if current_time - last_status_time >= status_interval:
        elapsed = int(current_time - start_time)
        print(f"[{elapsed}s] Processing SKU: {sku} ({product_name})")
        last_status_time = current_time
   # 1️⃣ Select donor and receiver dynamically
#    print("shank entering donor and receiver loop")
#    print("SHANK LOOP START FOR SKU: ", sku)
    donor, donor_found = select_donor(index)
#    receiver = select_receiver(index)
    # 2️⃣ Perform transfer if donor found and donor != receiver
#    print("shank checking if donor_found and donor = receiver")
#    if donor_found and donor != receiver:
#        print("shank transfering unit from donor to receiver")
        # Transfer 1 unit
#        df.loc[index, inv_columns[donor]] -= 1       # Subtract 1 from donor inventory
#        df.loc[index, sales_columns[receiver]] += 1 # Add 1 to receiver sales

        # Log the transfer
#        transfers.append({
#            'SKU': sku,
#            'Product Name': product_name,
#            'Category': category,
#            'From Store': donor,
#            'To Store': receiver,
#            'Amount': 1
#        })

    # 3️⃣ If no donor found, call fallback function
#    elif not donor_found:
#        fallback_transfer(index, receiver)  # You will define this function later



# Create a new DataFrame from the transfers list
transfers_df = pd.DataFrame(transfers, columns=['SKU', 'Product Name', 'Category', 'From Store', 'To Store', 'Amount'])
#print("Shank created a df transfers_df")


# Save the result to a new CSV file
transfers_df.to_csv('clearance_transfers_output_sarnia.csv', index=False)

# Store the updated available numbers at each store for each SKU
for _, row in df.iterrows():
        for store in sales_columns.keys():  # <-- use sales_columns.keys() instead of store_columns
            updated_available_numbers[store].append(row[inv_columns[store]])  # updated inventory

updated_available_df = pd.DataFrame(updated_available_numbers, columns=['Chatham', 'Exmoouth', 'Lakeshore', 'Trudeau'])

updated_available_df = pd.concat([
      df[['SKU', 'Product Name', 'Category', 'ChathamInv', 'ExmouthInv', 'LakeshoreInv', 'TrudeauInv']],
      updated_available_df
], axis=1)

# Save the updated available numbers to a new CSV file
updated_available_df.to_csv('updated_available_numbers_sarnia.csv', index=False)

end_time = time.time()
print(f"Total execution time: {end_time - start_time:.2f} seconds")
# Out:
# Clearance Transfer Start: 2025-11-25 19:35:29
# Shank | SKU=307088_1g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 2), ('Lakeshore', 3), ('Trudeau', 1)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=1236_Platinum | Units Sold Array=[('Chatham', 6), ('Exmouth', 6), ('Lakeshore', 7), ('Trudeau', 7)]
# Shank | SKU=110745_15 caps___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=110496_30ml___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 4), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=110494_30ml___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 2), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=106453_1g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shank | SKU=303219_0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 6), ('Lakeshore', 2), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=312394_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 2)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=303089_1g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 3), ('Lakeshore', 3), ('Trudeau', 1)]
# Shank | SKU=313213_1x0.5g___ | Units Sold Array=[('Chatham', 6), ('Exmouth', 1), ('Lakeshore', 3), ('Trudeau', 8)]
# Shank | SKU=313143_1g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 3)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=313123_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 4), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=303120_1g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 0), ('Lakeshore', 3), ('Trudeau', 1)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=106644_3.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 8), ('Lakeshore', 4), ('Trudeau', 3)]
# Shank | SKU=303174_1g___ | Units Sold Array=[('Chatham', 7), ('Exmouth', 1), ('Lakeshore', 3), ('Trudeau', 1)]
# Shank | SKU=106811_14g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=102806_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 5), ('Lakeshore', 1), ('Trudeau', 2)]
# Shank | SKU=317179_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shank | SKU=317196_1x2g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=110994_5x0.6g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=317244_1x1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=307192_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 3), ('Lakeshore', 1), ('Trudeau', 2)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=110595_80x0.35g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 0)]
# Shank | SKU=110596_7x0.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 9), ('Lakeshore', 8), ('Trudeau', 2)]
# Shank | SKU=102004_5 Pack___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=105543_5 Pack___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=106858_14g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=113169_7g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108743_7g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 5), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108661_3.5g___ | Units Sold Array=[('Chatham', 6), ('Exmouth', 4), ('Lakeshore', 0), ('Trudeau', 11)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=108805_14x0.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 4)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=108696_14g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=110007_14g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 2), ('Lakeshore', 2), ('Trudeau', 8)]
# Shank | SKU=110007_28g___ | Units Sold Array=[('Chatham', 10), ('Exmouth', 9), ('Lakeshore', 8), ('Trudeau', 7)]
# Shank | SKU=108145_10x0.35g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 6), ('Lakeshore', 9), ('Trudeau', 4)]
# Shank | SKU=108808_14x0.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 3), ('Lakeshore', 2), ('Trudeau', 4)]
# Shank | SKU=315245_2g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=110532_3.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 2), ('Lakeshore', 2), ('Trudeau', 2)]
# Shank | SKU=110677_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=317260_3x0.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 2), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=110916_7x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=110716_28g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 2), ('Lakeshore', 3), ('Trudeau', 4)]
# Shank | SKU=313282_3x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 5)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=305245_1g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 2), ('Lakeshore', 4), ('Trudeau', 0)]
# Shank | SKU=305234_1g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 2), ('Lakeshore', 3), ('Trudeau', 3)]
# Shank | SKU=305250_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 3), ('Trudeau', 4)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=305253_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 4), ('Trudeau', 2)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=315131_3x0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=305222_1g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 3), ('Lakeshore', 1), ('Trudeau', 5)]
# Shank | SKU=305236_1g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 6), ('Lakeshore', 1), ('Trudeau', 2)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=315177_3x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 3)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=104276_10x0.5g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 5), ('Lakeshore', 3), ('Trudeau', 4)]
# Shank | SKU=317131_3x0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=327077_355ml___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=327068_355ml___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=313276_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shank | SKU=333186_1 Pack___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=313199_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 3)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=108711_10x0.5g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=111157_28g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 4), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=108301_28g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=111158_14g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=110798_3.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 4), ('Lakeshore', 2), ('Trudeau', 5)]
# Shank | SKU=110072_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 2)]
# Shank | SKU=105482_28g___ | Units Sold Array=[('Chatham', 7), ('Exmouth', 6), ('Lakeshore', 3), ('Trudeau', 10)]
# Shank | SKU=105481_28g___ | Units Sold Array=[('Chatham', 6), ('Exmouth', 5), ('Lakeshore', 2), ('Trudeau', 1)]
# Shank | SKU=105480_28g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=105664_28g___ | Units Sold Array=[('Chatham', 17), ('Exmouth', 2), ('Lakeshore', 3), ('Trudeau', 15)]
# Shank | SKU=105666_28g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 5), ('Lakeshore', 3), ('Trudeau', 1)]
# Shank | SKU=105609_70x0.4g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=105720_28g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 2), ('Trudeau', 1)]
# Shank | SKU=105786_3.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 3), ('Lakeshore', 2), ('Trudeau', 2)]
# Shank | SKU=105279_28g___ | Units Sold Array=[('Chatham', 10), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 4)]
# Shank | SKU=339581_5 Pack___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 2), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=111052_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=111095_1x1g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 3), ('Lakeshore', 1), ('Trudeau', 5)]
# Shank | SKU=111094_14x0.5g___ | Units Sold Array=[('Chatham', 7), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 4)]
# Shank | SKU=111049_14g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=111007_5x0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 8)]
# Shank | SKU=110966_3.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 2)]
# Shank | SKU=110814_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=301006_0.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 2), ('Trudeau', 1)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=111141_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=108522_14g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=108520_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=106716_1x1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=102664_14g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106712_14g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=111001_5x0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shank | SKU=111091_1x1g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 0), ('Lakeshore', 3), ('Trudeau', 9)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=113306_1x1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=106794_7g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=302341_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=312225_1x1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=105349_1x1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 4), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=105351_1x1g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 2), ('Lakeshore', 2), ('Trudeau', 1)]
# Shank | SKU=312220_1.2g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 3), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=302099_2g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=312049_1.2g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 2), ('Lakeshore', 4), ('Trudeau', 2)]
# Shank | SKU=302052_1.2g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 3)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=302054_1.2g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 5)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=312279_1.2g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 12)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=104252_5x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=110830_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=110706_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 2), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=111070_7g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=104096_14g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=104143_1x1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=110473_5x0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 4), ('Lakeshore', 1), ('Trudeau', 0)]
# Shank | SKU=102875_2x1g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 13), ('Lakeshore', 9), ('Trudeau', 21)]
# Shank | SKU=103428_14g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 3), ('Lakeshore', 1), ('Trudeau', 11)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=102878_14g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 5), ('Lakeshore', 1), ('Trudeau', 5)]
# Shank | SKU=105866_7g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=315259_3x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 3), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=319626_3x0.5g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 6), ('Lakeshore', 1), ('Trudeau', 0)]
# Shank | SKU=110903_10x0.35g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 5), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=110149_14g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=111066_14g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=101870_14g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=101870_3.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 4), ('Lakeshore', 2), ('Trudeau', 5)]
# Shank | SKU=102071_12x0.5g___ | Units Sold Array=[('Chatham', 8), ('Exmouth', 5), ('Lakeshore', 5), ('Trudeau', 2)]
# Shank | SKU=317278_2g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=111195_3x0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 4), ('Lakeshore', 2), ('Trudeau', 4)]
# Shank | SKU=110971_14g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 3), ('Lakeshore', 1), ('Trudeau', 3)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=111012_6x0.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 2), ('Lakeshore', 9), ('Trudeau', 3)]
# Shank | SKU=111062_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 10)]
# Shank | SKU=307205_1g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 0), ('Lakeshore', 4), ('Trudeau', 3)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=111153_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=315071_2g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=110851_7g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=110826_14g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=111068_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 3), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=111067_7g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shank | SKU=313240_5x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=317257_1x1.25g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 5), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=317256_1x1.25g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 3), ('Lakeshore', 4), ('Trudeau', 3)]
# Shank | SKU=317233_1x1.25g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 3)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=317284_1x1.25g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 4)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=317174_3x0.5g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 7), ('Lakeshore', 0), ('Trudeau', 3)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=108402_1 Pack___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=108406_1 Pack___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=108674_10x0.35g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=101855_7g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=101857_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108732_7g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 2)]
# Shank | SKU=101679_10x0.35g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 0), ('Trudeau', 3)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=108377_10x0.35g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 3), ('Trudeau', 2)]
# Shank | SKU=105728_7g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 3), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=111072_7g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=302383_2g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=315232_1x1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=315221_1x1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=315120_1x1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=317243_3x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 3), ('Lakeshore', 3), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=310207_2g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 2), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=317241_3x0.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 3), ('Lakeshore', 4), ('Trudeau', 2)]
# Shank | SKU=317228_3x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 2), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=317212_3x0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 5), ('Lakeshore', 5), ('Trudeau', 4)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=105179_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=106043_30ml___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=309065_1g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 7), ('Lakeshore', 0), ('Trudeau', 2)]
# Shank | SKU=110936_14g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108746_5x0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108728_7g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=302351_1g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 5), ('Lakeshore', 10), ('Trudeau', 2)]
# Shank | SKU=312093_5x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 7)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=312012_1x0.75g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 1), ('Lakeshore', 2), ('Trudeau', 0)]
# Shank | SKU=302242_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 5), ('Lakeshore', 2), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=105162_90 caps___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=327089_355ml___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 2), ('Lakeshore', 4), ('Trudeau', 1)]
# Shank | SKU=108574_4x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=300755_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=108525_28g___ | Units Sold Array=[('Chatham', 10), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 0)]
# Shank | SKU=315295_1x1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=102731_28g___ | Units Sold Array=[('Chatham', 6), ('Exmouth', 7), ('Lakeshore', 3), ('Trudeau', 4)]
# Shank | SKU=108136_1x1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=101772_30 caps___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=105704_4x0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shank | SKU=106881_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106691_10x0.5g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106125_3.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=303115_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 4), ('Trudeau', 2)]
# Shank | SKU=106959_7g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 0), ('Lakeshore', 4), ('Trudeau', 4)]
# Shank | SKU=106693_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 6), ('Trudeau', 2)]
# Shank | SKU=106580_1g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106580_7g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108064_1x0.75g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 5), ('Trudeau', 1)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=335183_30x1 Pack___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 2), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=319026_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 2), ('Trudeau', 1)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=309601_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=305165_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=302272_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=300641_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 3)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=104106_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=104107_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106681_8.23ml___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=106680_8.23ml___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=322025_355ml___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=111096_1x1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 6), ('Lakeshore', 3), ('Trudeau', 2)]
# Shank | SKU=110816_28g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=110816_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108357_1x1g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 2), ('Lakeshore', 0), ('Trudeau', 3)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=110687_3.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 7), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=108304_14g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 5), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=108304_28g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 2), ('Trudeau', 2)]
# Shank | SKU=330367_1 Pack___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 5), ('Lakeshore', 9), ('Trudeau', 3)]
# Shank | SKU=300479_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 2)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=302283_2g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=105554_3.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106783_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 4), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=105555_5x0.5g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 3), ('Lakeshore', 3), ('Trudeau', 1)]
# Shank | SKU=108557_5x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 2), ('Trudeau', 5)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=108518_7g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=106756_30ml___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106969_28g___ | Units Sold Array=[('Chatham', 7), ('Exmouth', 4), ('Lakeshore', 3), ('Trudeau', 10)]
# Shank | SKU=108603_5 Pack___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=303221_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=303100_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 3)]
# Shank | SKU=303202_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=303087_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shank | SKU=110912_1x1g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 6), ('Lakeshore', 2), ('Trudeau', 6)]
# Shank | SKU=312360_1g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=302332_0.95g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 6), ('Lakeshore', 2), ('Trudeau', 4)]
# Shank | SKU=302262_0.95g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 6), ('Trudeau', 1)]
# Shank | SKU=332114_2 Pack___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 2), ('Trudeau', 1)]
# Shank | SKU=332068_2 Pack___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 0), ('Lakeshore', 10), ('Trudeau', 2)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=302400_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 5), ('Lakeshore', 0), ('Trudeau', 6)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=310432_3x0.5g___ | Units Sold Array=[('Chatham', 10), ('Exmouth', 10), ('Lakeshore', 7), ('Trudeau', 6)]
# Shank | SKU=105693_3.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=105173_100 caps___ | Units Sold Array=[('Chatham', 7), ('Exmouth', 1), ('Lakeshore', 7), ('Trudeau', 8)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=104322_2x1g___ | Units Sold Array=[('Chatham', 45), ('Exmouth', 28), ('Lakeshore', 4), ('Trudeau', 21)]
# Shank | SKU=104004_28g___ | Units Sold Array=[('Chatham', 12), ('Exmouth', 5), ('Lakeshore', 1), ('Trudeau', 3)]
# Shank | SKU=104004_7g___ | Units Sold Array=[('Chatham', 10), ('Exmouth', 29), ('Lakeshore', 3), ('Trudeau', 23)]
# Shank | SKU=104191_14x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=311000_2.38g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=104330_7x0.5g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 8), ('Lakeshore', 11), ('Trudeau', 9)]
# Shank | SKU=104328_28g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 2), ('Lakeshore', 2), ('Trudeau', 4)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=301056_1g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=312121_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 4), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=105709_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=312004_1x1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 3), ('Lakeshore', 2), ('Trudeau', 3)]
# Shank | SKU=312119_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 4), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=302298_1g___ | Units Sold Array=[('Chatham', 6), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=312307_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shank | SKU=110920_6 Pack___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=308083_1g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 2), ('Lakeshore', 2), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=312271_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=313263_1x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=313260_1g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 8)]
# Shank | SKU=313225_3x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108782_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108783_14g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108783_7g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=315325_1.2g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 2)]
# Shank | SKU=315334_1.2g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106415_1x1g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 3), ('Lakeshore', 1), ('Trudeau', 5)]
# Shank | SKU=105270_14x0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=105365_3x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=105271_3x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=105603_3x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 6)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=106088_14g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=104113_3.5g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=105268_3.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=105658_1x1g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=105376_10x0.4g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=313166_2g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=110119_50ml___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=305175_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 2), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=313181_3x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 2), ('Lakeshore', 2), ('Trudeau', 4)]
# Shank | SKU=101986_7g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 1), ('Lakeshore', 2), ('Trudeau', 0)]
# Shank | SKU=102150_3x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 1), ('Lakeshore', 3), ('Trudeau', 2)]
# Shank | SKU=102150_10x0.5g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=101581_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=103766_10x0.5g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=307207_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=104313_5x1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=309058_1g___ | Units Sold Array=[('Chatham', 8), ('Exmouth', 17), ('Lakeshore', 8), ('Trudeau', 7)]
# Shank | SKU=104312_7g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=104261_7g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 2)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# ...
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=312313_2x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 4), ('Trudeau', 2)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=312312_6x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=312283_6x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=317117_1g___ | Units Sold Array=[('Chatham', 10), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 7)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=315034_2x0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=315152_1g___ | Units Sold Array=[('Chatham', 7), ('Exmouth', 3), ('Lakeshore', 2), ('Trudeau', 8)]
# Shank | SKU=112200_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 4)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=112183_14g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 5)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=112178_14g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=305092_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 8), ('Lakeshore', 2), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=305048_1g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 3)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=305209_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 6), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=305220_0.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 3)]
# Shank | SKU=315269_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=327007_355ml___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=303070_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=313232_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=303056_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=312395_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=312213_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=312207_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=312123_1g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=312047_1x1g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 5), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=310241_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=315085_1x1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=312147_3x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 3), ('Trudeau', 2)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=312101_3x0.5g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 4), ('Lakeshore', 1), ('Trudeau', 2)]
# Shank | SKU=102355_14x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 8), ('Lakeshore', 2), ('Trudeau', 1)]
# Shank | SKU=101662_14g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 15), ('Lakeshore', 3), ('Trudeau', 26)]
# Shank | SKU=101971_14x0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 17)]
# Shank | SKU=106567_28g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 2), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=106583_10x0.3g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 3), ('Trudeau', 3)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=106353_5x0.3g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 3), ('Trudeau', 1)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=106903_3.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106982_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106455_3x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 3), ('Trudeau', 0)]
# Shank | SKU=333173_4 Pack___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=104300_3.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 2), ('Trudeau', 1)]
# Shank | SKU=104288_3.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 3), ('Lakeshore', 2), ('Trudeau', 2)]
# Shank | SKU=112113_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 2), ('Trudeau', 3)]
# Shank | SKU=105574_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=105575_3x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=327031_355ml___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 6), ('Lakeshore', 1), ('Trudeau', 2)]
# Shank | SKU=313165_1x1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shank | SKU=332167_5x1 Pack___ | Units Sold Array=[('Chatham', 13), ('Exmouth', 8), ('Lakeshore', 4), ('Trudeau', 1)]
# Shank | SKU=303068_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=330487_5 Pack___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 2)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=102221_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=313083_5x0.5g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 10), ('Lakeshore', 1), ('Trudeau', 10)]
# Shank | SKU=102103_14g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=102103_7g___ | Units Sold Array=[('Chatham', 5), ('Exmouth', 2), ('Lakeshore', 0), ('Trudeau', 5)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=303093_0.5g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 5), ('Lakeshore', 2), ('Trudeau', 6)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=303110_1.2g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 1)]
# Shank | SKU=105789_28g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=303169_1.2g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 2), ('Trudeau', 6)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=300631_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=303049_1.2g___ | Units Sold Array=[('Chatham', 3), ('Exmouth', 4), ('Lakeshore', 3), ('Trudeau', 2)]
# Shank | SKU=303067_1.2g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=106597_3.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106492_14g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 3)]
# Shank | SKU=303217_1g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 2), ('Lakeshore', 2), ('Trudeau', 5)]
# Shank | SKU=343013_56ml___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=106293_30 caps___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=313105_1x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 1), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=106918_6x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=106686_6x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106998_2g___ | Units Sold Array=[('Chatham', 7), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 4)]
# Shank | SKU=103250_6x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 2), ('Trudeau', 1)]
# Shank | SKU=302278_1g___ | Units Sold Array=[('Chatham', 2), ('Exmouth', 3), ('Lakeshore', 3), ('Trudeau', 2)]
# Shank | SKU=313255_5x0.25g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 6), ('Lakeshore', 2), ('Trudeau', 2)]
# Shank | SKU=312259_1x1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 1), ('Trudeau', 3)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=305247_1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 2)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=343001_390g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=302231_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=312310_5x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=302375_1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108723_7g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 2), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=108727_7g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Trudeau
# Shashank receiver FINAL :  Chatham
# Shank | SKU=108289_14g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shank | SKU=110055_3.5g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 2), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=108725_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=106785_14g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 0), ('Lakeshore', 1), ('Trudeau', 1)]
# Shank | SKU=313303_3x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Exmouth
# Shank | SKU=106806_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 4), ('Lakeshore', 1), ('Trudeau', 2)]
# Shank | SKU=303218_0.95g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 3)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=106964_3.5g___ | Units Sold Array=[('Chatham', 6), ('Exmouth', 3), ('Lakeshore', 1), ('Trudeau', 11)]
# Shank | SKU=106424_2x1g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 3), ('Trudeau', 2)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Lakeshore
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Lakeshore
# Shank | SKU=303155_0.95g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 1)]
# Shashank donor FINAL :  Chatham
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=106620_7x0.5g___ | Units Sold Array=[('Chatham', 0), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Chatham
# Shank | SKU=305225_0.95g___ | Units Sold Array=[('Chatham', 6), ('Exmouth', 7), ('Lakeshore', 2), ('Trudeau', 7)]
# Shank | SKU=106977_7g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 1), ('Lakeshore', 0), ('Trudeau', 2)]
# Shashank donor FINAL :  Exmouth
# Shashank receiver FINAL :  Trudeau
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Trudeau
# Shank | SKU=113276_1x1g___ | Units Sold Array=[('Chatham', 1), ('Exmouth', 0), ('Lakeshore', 0), ('Trudeau', 0)]
# Shashank donor FINAL :  Lakeshore
# Shashank receiver FINAL :  Chatham
# Shank | SKU=308084_1.2g___ | Units Sold Array=[('Chatham', 4), ('Exmouth', 3), ('Lakeshore', 0), ('Trudeau', 1)]
# Total execution time: 1.35 seconds

# %%
import csv

def condense_csv(input_file, output_file):
    data = {}

    # Read CSV file and store data in a dictionary
    with open(input_file, 'r') as csvfile:
        reader = csv.reader(csvfile)
        headers = next(reader)  # Assuming the first row contains headers
        for row in reader:
            key = tuple(row[i] for i in [0, 3, 4])  # Columns 1, 4, and 5
            if key in data:
                data[key][5] = str(int(data[key][5]) + int(row[5]))  # Combine values in column 6
            else:
                data[key] = row

    # Write condensed data to a new CSV file
    with open(output_file, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(headers)
        for row in data.values():
            writer.writerow(row)

# Example usage
input_file = 'clearance_transfers_output_sarnia.csv'  # Replace with your CSV file path
output_file = 'Clearance_Transfers_Output_Sarnia.csv'  # Replace with the desired output file path
condense_csv(input_file, output_file)
